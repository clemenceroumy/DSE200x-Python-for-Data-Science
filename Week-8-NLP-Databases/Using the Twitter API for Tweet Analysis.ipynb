# %% [markdown]
# # Twitter data
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Twitter API Access
#
# Twitter implements OAuth 1.0A as its standard authentication mechanism, and in order to use it to make requests to Twitter's API, you'll need to go to https://dev.twitter.com/apps and create a sample application.
#
# Choose any name for your application, write a description and use `http://google.com` for the website.
#
# Under **Key and Access Tokens**, there are four primary identifiers you'll need to note for an OAuth 1.0A workflow:
# * consumer key,
# * consumer secret,
# * access token, and
# * access token secret (Click on Create Access Token to create those).
#
# Note that you will need an ordinary Twitter account in order to login, create an app, and get these credentials.

# %% [markdown]
# The first time you execute the notebook, add all credentials so that you can save them in the `pkl` file, then you can remove the secret keys from the notebook because they will just be loaded from the `pkl` file.
#
# The `pkl` file contains sensitive information that can be used to take control of your twitter acccount, **do not share it**.

# %%
import pickle
import os

# %%
if not os.path.exists('secret_twitter_credentials.pkl'):
    Twitter={}
    Twitter['Consumer Key'] = ''
    Twitter['Consumer Secret'] = ''
    Twitter['Access Token'] = ''
    Twitter['Access Token Secret'] = ''
    with open('secret_twitter_credentials.pkl','wb') as f:
        pickle.dump(Twitter, f)
else:
    Twitter=pickle.load(open('secret_twitter_credentials.pkl','rb'))

# %% [markdown]
# Install the `twitter` package to interface with the Twitter API

# %%
# !pip install twitter
# Out:
# Collecting twitter
#   Downloading https://files.pythonhosted.org/packages/85/e2/f602e3f584503f03e0389491b251464f8ecfe2596ac86e6b9068fe7419d3/twitter-1.18.0-py2.py3-none-any.whl (54kB)
# Installing collected packages: twitter
# Successfully installed twitter-1.18.0

# %% [markdown]
# ## Example 1. Authorizing an application to access Twitter account data

# %%
import twitter

auth = twitter.oauth.OAuth(Twitter['Access Token'],
                           Twitter['Access Token Secret'],
                           Twitter['Consumer Key'],
                           Twitter['Consumer Secret'])

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x000001EA9500B4A8>

# %% [markdown]
# ## Example 2. Retrieving trends

# %% [markdown]
# Twitter identifies locations using the Yahoo! Where On Earth ID.
#
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/
#
# look at the BOSS placefinder here: https://developer.yahoo.com/boss/placefinder/

# %%
WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# %% [markdown]
# Look for the WOEID for [san-diego](http://woeid.rosselliot.co.nz/lookup/san%20diego%20%20ca)
#
# You can change it to another location.

# %%
LOCAL_WOE_ID=2487889

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)
local_trends = twitter_api.trends.place(_id=LOCAL_WOE_ID)

# %%
world_trends[:2]
# Out:
# [{'trends': [{'name': '#INDvAUS',
#     'url': 'http://twitter.com/search?q=%23INDvAUS',
#     'promoted_content': None,
#     'query': '%23INDvAUS',
#     'tweet_volume': 57597},
#    {'name': '#AskStar',
#     'url': 'http://twitter.com/search?q=%23AskStar',
#     'promoted_content': None,
#     'query': '%23AskStar',
#     'tweet_volume': 10001},
#    {'name': '#キリチャレの日',
#     'url': 'http://twitter.com/search?q=%23%E3%82%AD%E3%83%AA%E3%83%81%E3%83%A3%E3%83%AC%E3%81%AE%E6%97%A5',
#     'promoted_content': None,
#     'query': '%23%E3%82%AD%E3%83%AA%E3%83%81%E3%83%A3%E3%83%AC%E3%81%AE%E6%97%A5',
#     'tweet_volume': 31913},
#    {'name': '#あなたと気が合いそうなア二メキャラ',
#     'url': 'http://twitter.com/search?q=%23%E3%81%82%E3%81%AA%E3%81%9F%E3%81%A8%E6%B0%97%E3%81%8C%E5%90%88%E3%81%84%E3%81%9D%E3%81%86%E3%81%AA%E3%82%A2%E4%BA%8C%E3%83%A1%E3%82%AD%E3%83%A3%E3%83%A9',
#     'promoted_content': None,
#     'query': '%23%E3%81%82%E3%81%AA%E3%81%9F%E3%81%A8%E6%B0%97%E3%81%8C%E5%90%88%E3%81%84%E3%81%9D%E3%81%86%E3%81%AA%E3%82%A2%E4%BA%8C%E3%83%A1%E3%82%AD%E3%83%A3%E3%83%A9',
#     'tweet_volume': 22857},
#    {'name': '#AybükeYalçın',
#     'url': 'http://twitter.com/search?q=%23Ayb%C3%BCkeYal%C3%A7%C4%B1n',
#     'promoted_content': None,
#     'query': '%23Ayb%C3%BCkeYal%C3%A7%C4%B1n',
#     'tweet_volume': 26275},
#    {'name': 'アニメキャラ',
#     'url': 'http://twitter.com/search?q=%E3%82%A2%E3%83%8B%E3%83%A1%E3%82%AD%E3%83%A3%E3%83%A9',
#     'promoted_content': None,
#     'query': '%E3%82%A2%E3%83%8B%E3%83%A1%E3%82%AD%E3%83%A3%E3%83%A9',
#     'tweet_volume': 32664},
#    {'name': 'BizHariç Olimpiyattaydılar',
#     'url': 'http://twitter.com/search?q=%22BizHari%C3%A7+Olimpiyattayd%C4%B1lar%22',
#     'promoted_content': None,
#     'query': '%22BizHari%C3%A7+Olimpiyattayd%C4%B1lar%22',
#     'tweet_volume': None},
#    {'name': 'KENTA',
#     'url': 'http://twitter.com/search?q=KENTA',
#     'promoted_content': None,
#     'query': 'KENTA',
#     'tweet_volume': 29317},
#    {'name': '久保くん',
#     'url': 'http://twitter.com/search?q=%E4%B9%85%E4%BF%9D%E3%81%8F%E3%82%93',
#     'promoted_content': None,
#     'query': '%E4%B9%85%E4%BF%9D%E3%81%8F%E3%82%93',
#     'tweet_volume': None},
#    {'name': 'エルサルバドル',
#     'url': 'http://twitter.com/search?q=%E3%82%A8%E3%83%AB%E3%82%B5%E3%83%AB%E3%83%90%E3%83%89%E3%83%AB',
#     'promoted_content': None,
#     'query': '%E3%82%A8%E3%83%AB%E3%82%B5%E3%83%AB%E3%83%90%E3%83%89%E3%83%AB',
#     'tweet_volume': 34085},
#    {'name': '代表戦',
#     'url': 'http://twitter.com/search?q=%E4%BB%A3%E8%A1%A8%E6%88%A6',
#     'promoted_content': None,
#     'query': '%E4%BB%A3%E8%A1%A8%E6%88%A6',
#     'tweet_volume': 12078},
#    {'name': 'MazlumunAhı İndirirŞahı',
#     'url': 'http://twitter.com/search?q=%22MazlumunAh%C4%B1+%C4%B0ndirir%C5%9Eah%C4%B1%22',
#     'promoted_content': None,
#     'query': '%22MazlumunAh%C4%B1+%C4%B0ndirir%C5%9Eah%C4%B1%22',
#     'tweet_volume': None},
#    {'name': 'Dhawan',
#     'url': 'http://twitter.com/search?q=Dhawan',
#     'promoted_content': None,
#     'query': 'Dhawan',
#     'tweet_volume': None},
#    {'name': '声の王子様',
#     'url': 'http://twitter.com/search?q=%E5%A3%B0%E3%81%AE%E7%8E%8B%E5%AD%90%E6%A7%98',
#     'promoted_content': None,
#     'query': '%E5%A3%B0%E3%81%AE%E7%8E%8B%E5%AD%90%E6%A7%98',
#     'tweet_volume': 52736},
#    {'name': '永井選手',
#     'url': 'http://twitter.com/search?q=%E6%B0%B8%E4%BA%95%E9%81%B8%E6%89%8B',
#     'promoted_content': None,
#     'query': '%E6%B0%B8%E4%BA%95%E9%81%B8%E6%89%8B',
#     'tweet_volume': None},
#    {'name': '永井2点目',
#     'url': 'http://twitter.com/search?q=%E6%B0%B8%E4%BA%952%E7%82%B9%E7%9B%AE',
#     'promoted_content': None,
#     'query': '%E6%B0%B8%E4%BA%952%E7%82%B9%E7%9B%AE',
#     'tweet_volume': None},
#    {'name': '#njdominion',
#     'url': 'http://twitter.com/search?q=%23njdominion',
#     'promoted_content': None,
#     'query': '%23njdominion',
#     'tweet_volume': 47481},
#    {'name': '#SachinOpensAgain',
#     'url': 'http://twitter.com/search?q=%23SachinOpensAgain',
#     'promoted_content': None,
#     'query': '%23SachinOpensAgain',
#     'tweet_volume': None},
#    {'name': '#AUSITA',
#     'url': 'http://twitter.com/search?q=%23AUSITA',
#     'promoted_content': None,
#     'query': '%23AUSITA',
#     'tweet_volume': None},
#    {'name': '#طلع_وجهك',
#     'url': 'http://twitter.com/search?q=%23%D8%B7%D9%84%D8%B9_%D9%88%D8%AC%D9%87%D9%83',
#     'promoted_content': None,
#     'query': '%23%D8%B7%D9%84%D8%B9_%D9%88%D8%AC%D9%87%D9%83',
#     'tweet_volume': 34434},
#    {'name': '#pazar',
#     'url': 'http://twitter.com/search?q=%23pazar',
#     'promoted_content': None,
#     'query': '%23pazar',
#     'tweet_volume': 26305},
#    {'name': '#daihyo',
#     'url': 'http://twitter.com/search?q=%23daihyo',
#     'promoted_content': None,
#     'query': '%23daihyo',
#     'tweet_volume': 26968},
#    {'name': '#あなたは攻めなのか受けなのか',
#     'url': 'http://twitter.com/search?q=%23%E3%81%82%E3%81%AA%E3%81%9F%E3%81%AF%E6%94%BB%E3%82%81%E3%81%AA%E3%81%AE%E3%81%8B%E5%8F%97%E3%81%91%E3%81%AA%E3%81%AE%E3%81%8B',
#     'promoted_content': None,
#     'query': '%23%E3%81%82%E3%81%AA%E3%81%9F%E3%81%AF%E6%94%BB%E3%82%81%E3%81%AA%E3%81%AE%E3%81%8B%E5%8F%97%E3%81%91%E3%81%AA%E3%81%AE%E3%81%8B',
#     'tweet_volume': None},
#    {'name': '#鉄腕DASH',
#     'url': 'http://twitter.com/search?q=%23%E9%89%84%E8%85%95DASH',
#     'promoted_content': None,
#     'query': '%23%E9%89%84%E8%85%95DASH',
#     'tweet_volume': 12637},
#    {'name': '#RagazzeMondiali',
#     'url': 'http://twitter.com/search?q=%23RagazzeMondiali',
#     'promoted_content': None,
#     'query': '%23RagazzeMondiali',
#     'tweet_volume': None},
#    {'name': '#AUSvIND',
#     'url': 'http://twitter.com/search?q=%23AUSvIND',
#     'promoted_content': None,
#     'query': '%23AUSvIND',
#     'tweet_volume': None},
#    {'name': '#Marr',
#     'url': 'http://twitter.com/search?q=%23Marr',
#     'promoted_content': None,
#     'query': '%23Marr',
#     'tweet_volume': 15037},
#    {'name': '#المداومين_اليوم',
#     'url': 'http://twitter.com/search?q=%23%D8%A7%D9%84%D9%85%D8%AF%D8%A7%D9%88%D9%85%D9%8A%D9%86_%D8%A7%D9%84%D9%8A%D9%88%D9%85',
#     'promoted_content': None,
#     'query': '%23%D8%A7%D9%84%D9%85%D8%AF%D8%A7%D9%88%D9%85%D9%8A%D9%86_%D8%A7%D9%84%D9%8A%D9%88%D9%85',
#     'tweet_volume': 12021},
#    {'name': '#protectmamamoo',
#     'url': 'http://twitter.com/search?q=%23protectmamamoo',
#     'promoted_content': None,
#     'query': '%23protectmamamoo',
#     'tweet_volume': 48342},
#    {'name': '#kitapokuyalım',
#     'url': 'http://twitter.com/search?q=%23kitapokuyal%C4%B1m',
#     'promoted_content': None,
#     'query': '%23kitapokuyal%C4%B1m',
#     'tweet_volume': None},
#    {'name': '#IdolCity',
#     'url': 'http://twitter.com/search?q=%23IdolCity',
#     'promoted_content': None,
#     'query': '%23IdolCity',
#     'tweet_volume': None},
#    {'name': '#モヤさま',
#     'url': 'http://twitter.com/search?q=%23%E3%83%A2%E3%83%A4%E3%81%95%E3%81%BE',
#     'promoted_content': None,
#     'query': '%23%E3%83%A2%E3%83%A4%E3%81%95%E3%81%BE',
#     'tweet_volume': None},
#    {'name': '#امنيتك_التي_تتمناها',
#     'url': 'http://twitter.com/search?q=%23%D8%A7%D9%85%D9%86%D9%8A%D8%AA%D9%83_%D8%A7%D9%84%D8%AA%D9%8A_%D8%AA%D8%AA%D9%85%D9%86%D8%A7%D9%87%D8%A7',
#     'promoted_content': None,
#     'query': '%23%D8%A7%D9%85%D9%86%D9%8A%D8%AA%D9%83_%D8%A7%D9%84%D8%AA%D9%8A_%D8%AA%D8%AA%D9%85%D9%86%D8%A7%D9%87%D8%A7',
#     'tweet_volume': 16328},
#    {'name': '#ComradesMarathon2019',
#     'url': 'http://twitter.com/search?q=%23ComradesMarathon2019',
#     'promoted_content': None,
#     'query': '%23ComradesMarathon2019',
#     'tweet_volume': 10018},
#    {'name': '#SundayMorning',
#     'url': 'http://twitter.com/search?q=%23SundayMorning',
#     'promoted_content': None,
#     'query': '%23SundayMorning',
#     'tweet_volume': 13045},
#    {'name': '#イッテQ',
#     'url': 'http://twitter.com/search?q=%23%E3%82%A4%E3%83%83%E3%83%86Q',
#     'promoted_content': None,
#     'query': '%23%E3%82%A4%E3%83%83%E3%83%86Q',
#     'tweet_volume': None},
#    {'name': '#SundayThoughts',
#     'url': 'http://twitter.com/search?q=%23SundayThoughts',
#     'promoted_content': None,
#     'query': '%23SundayThoughts',
#     'tweet_volume': 22852},
#    {'name': '#RespectOurEuphoria',
#     'url': 'http://twitter.com/search?q=%23RespectOurEuphoria',
#     'promoted_content': None,
#     'query': '%23RespectOurEuphoria',
#     'tweet_volume': 291355},
#    {'name': '#日本代表',
#     'url': 'http://twitter.com/search?q=%23%E6%97%A5%E6%9C%AC%E4%BB%A3%E8%A1%A8',
#     'promoted_content': None,
#     'query': '%23%E6%97%A5%E6%9C%AC%E4%BB%A3%E8%A1%A8',
#     'tweet_volume': None},
#    {'name': '#avrupastudyosu',
#     'url': 'http://twitter.com/search?q=%23avrupastudyosu',
#     'promoted_content': None,
#     'query': '%23avrupastudyosu',
#     'tweet_volume': None},
#    {'name': '#キリンチャレンジカップ2019',
#     'url': 'http://twitter.com/search?q=%23%E3%82%AD%E3%83%AA%E3%83%B3%E3%83%81%E3%83%A3%E3%83%AC%E3%83%B3%E3%82%B8%E3%82%AB%E3%83%83%E3%83%972019',
#     'promoted_content': None,
#     'query': '%23%E3%82%AD%E3%83%AA%E3%83%B3%E3%83%81%E3%83%A3%E3%83%AC%E3%83%B3%E3%82%B8%E3%82%AB%E3%83%83%E3%83%972019',
#     'tweet_volume': None},
#    {'name': '#KWMF2019',
#     'url': 'http://twitter.com/search?q=%23KWMF2019',
#     'promoted_content': None,
#     'query': '%23KWMF2019',
#     'tweet_volume': 35725},
#    {'name': '#GoMatildas',
#     'url': 'http://twitter.com/search?q=%23GoMatildas',
#     'promoted_content': None,
#     'query': '%23GoMatildas',
#     'tweet_volume': None},
#    {'name': '#AustraliaItalia',
#     'url': 'http://twitter.com/search?q=%23AustraliaItalia',
#     'promoted_content': None,
#     'query': '%23AustraliaItalia',
#     'tweet_volume': None},
#    {'name': '#サッカー日本代表',
#     'url': 'http://twitter.com/search?q=%23%E3%82%B5%E3%83%83%E3%82%AB%E3%83%BC%E6%97%A5%E6%9C%AC%E4%BB%A3%E8%A1%A8',
#     'promoted_content': None,
#     'query': '%23%E3%82%B5%E3%83%83%E3%82%AB%E3%83%BC%E6%97%A5%E6%9C%AC%E4%BB%A3%E8%A1%A8',
#     'tweet_volume': None},
#    {'name': '#岡崎体育',
#     'url': 'http://twitter.com/search?q=%23%E5%B2%A1%E5%B4%8E%E4%BD%93%E8%82%B2',
#     'promoted_content': None,
#     'query': '%23%E5%B2%A1%E5%B4%8E%E4%BD%93%E8%82%B2',
#     'tweet_volume': None},
#    {'name': '#RikMayall',
#     'url': 'http://twitter.com/search?q=%23RikMayall',
#     'promoted_content': None,
#     'query': '%23RikMayall',
#     'tweet_volume': None},
#    {'name': '#あなたはこんな印象の人',
#     'url': 'http://twitter.com/search?q=%23%E3%81%82%E3%81%AA%E3%81%9F%E3%81%AF%E3%81%93%E3%82%93%E3%81%AA%E5%8D%B0%E8%B1%A1%E3%81%AE%E4%BA%BA',
#     'promoted_content': None,
#     'query': '%23%E3%81%82%E3%81%AA%E3%81%9F%E3%81%AF%E3%81%93%E3%82%93%E3%81%AA%E5%8D%B0%E8%B1%A1%E3%81%AE%E4%BA%BA',
#     'tweet_volume': None},
#    {'name': '#パワスプ',
#     'url': 'http://twitter.com/search?q=%23%E3%83%91%E3%83%AF%E3%82%B9%E3%83%97',
#     'promoted_content': None,
#     'query': '%23%E3%83%91%E3%83%AF%E3%82%B9%E3%83%97',
#     'tweet_volume': None},
#    {'name': '#MilliTakımımız',
#     'url': 'http://twitter.com/search?q=%23MilliTak%C4%B1m%C4%B1m%C4%B1z',
#     'promoted_content': None,
#     'query': '%23MilliTak%C4%B1m%C4%B1m%C4%B1z',
#     'tweet_volume': None}],
#   'as_of': '2019-06-09T11:32:27Z',
#   'created_at': '2019-06-09T11:26:44Z',
#   'locations': [{'name': 'Worldwide', 'woeid': 1}]}]

# %%
trends=local_trends
print(type(trends))
print(list(trends[0].keys()))
print(trends[0]['trends'])
# Out:
# <class 'twitter.api.TwitterListResponse'>
# ['trends', 'as_of', 'created_at', 'locations']
# [{'name': '#UFC238', 'url': 'http://twitter.com/search?q=%23UFC238', 'promoted_content': None, 'query': '%23UFC238', 'tweet_volume': 132050}, {'name': '#NOME9', 'url': 'http://twitter.com/search?q=%23NOME9', 'promoted_content': None, 'query': '%23NOME9', 'tweet_volume': 31192}, {'name': '#WorldOceansDay', 'url': 'http://twitter.com/search?q=%23WorldOceansDay', 'promoted_content': None, 'query': '%23WorldOceansDay', 'tweet_volume': 155827}, {'name': '#NationalBestFriendsDay', 'url': 'http://twitter.com/search?q=%23NationalBestFriendsDay', 'promoted_content': None, 'query': '%23NationalBestFriendsDay', 'tweet_volume': 37104}, {'name': '#BestFriendsDay', 'url': 'http://twitter.com/search?q=%23BestFriendsDay', 'promoted_content': None, 'query': '%23BestFriendsDay', 'tweet_volume': 142984}, {'name': 'Austin Hedges', 'url': 'http://twitter.com/search?q=%22Austin+Hedges%22', 'promoted_content': None, 'query': '%22Austin+Hedges%22', 'tweet_volume': None}, {'name': 'Tatis', 'url': 'http://twitter.com/search?q=Tatis', 'promoted_content': None, 'query': 'Tatis', 'tweet_volume': None}, {'name': 'Toonami', 'url': 'http://twitter.com/search?q=Toonami', 'promoted_content': None, 'query': 'Toonami', 'tweet_volume': 13669}, {'name': 'KENTA', 'url': 'http://twitter.com/search?q=KENTA', 'promoted_content': None, 'query': 'KENTA', 'tweet_volume': 26162}, {'name': 'Dragon Lee', 'url': 'http://twitter.com/search?q=%22Dragon+Lee%22', 'promoted_content': None, 'query': '%22Dragon+Lee%22', 'tweet_volume': None}, {'name': 'henry cejudo', 'url': 'http://twitter.com/search?q=%22henry+cejudo%22', 'promoted_content': None, 'query': '%22henry+cejudo%22', 'tweet_volume': 15024}, {'name': 'Taichi', 'url': 'http://twitter.com/search?q=Taichi', 'promoted_content': None, 'query': 'Taichi', 'tweet_volume': None}, {'name': 'kumar rocker', 'url': 'http://twitter.com/search?q=%22kumar+rocker%22', 'promoted_content': None, 'query': '%22kumar+rocker%22', 'tweet_volume': 13825}, {'name': 'Ishii', 'url': 'http://twitter.com/search?q=Ishii', 'promoted_content': None, 'query': 'Ishii', 'tweet_volume': None}, {'name': 'Luxord', 'url': 'http://twitter.com/search?q=Luxord', 'promoted_content': None, 'query': 'Luxord', 'tweet_volume': None}, {'name': 'G1 Climax', 'url': 'http://twitter.com/search?q=%22G1+Climax%22', 'promoted_content': None, 'query': '%22G1+Climax%22', 'tweet_volume': None}, {'name': 'Nomura', 'url': 'http://twitter.com/search?q=Nomura', 'promoted_content': None, 'query': 'Nomura', 'tweet_volume': None}, {'name': 'Canelo', 'url': 'http://twitter.com/search?q=Canelo', 'promoted_content': None, 'query': 'Canelo', 'tweet_volume': None}, {'name': 'Naito', 'url': 'http://twitter.com/search?q=Naito', 'promoted_content': None, 'query': 'Naito', 'tweet_volume': None}, {'name': 'Tony Ferguson', 'url': 'http://twitter.com/search?q=%22Tony+Ferguson%22', 'promoted_content': None, 'query': '%22Tony+Ferguson%22', 'tweet_volume': None}, {'name': 'Roxas', 'url': 'http://twitter.com/search?q=Roxas', 'promoted_content': None, 'query': 'Roxas', 'tweet_volume': None}, {'name': 'Sanada', 'url': 'http://twitter.com/search?q=Sanada', 'promoted_content': None, 'query': 'Sanada', 'tweet_volume': None}, {'name': 'Jessica Eye', 'url': 'http://twitter.com/search?q=%22Jessica+Eye%22', 'promoted_content': None, 'query': '%22Jessica+Eye%22', 'tweet_volume': None}, {'name': 'Moraes', 'url': 'http://twitter.com/search?q=Moraes', 'promoted_content': None, 'query': 'Moraes', 'tweet_volume': 22758}, {'name': 'KH3 DLC', 'url': 'http://twitter.com/search?q=%22KH3+DLC%22', 'promoted_content': None, 'query': '%22KH3+DLC%22', 'tweet_volume': None}, {'name': 'Verb', 'url': 'http://twitter.com/search?q=Verb', 'promoted_content': None, 'query': 'Verb', 'tweet_volume': 13087}, {'name': 'Chase Owens', 'url': 'http://twitter.com/search?q=%22Chase+Owens%22', 'promoted_content': None, 'query': '%22Chase+Owens%22', 'tweet_volume': None}, {'name': 'moxley in the g1', 'url': 'http://twitter.com/search?q=%22mox ...

# %% [markdown]
# ## Example 3. Displaying API responses as pretty-printed JSON

# %%
import json

print((json.dumps(us_trends[:2], indent=1)))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "#njdominion",
#     "url": "http://twitter.com/search?q=%23njdominion",
#     "promoted_content": null,
#     "query": "%23njdominion",
#     "tweet_volume": 33717
#    },
#    {
#     "name": "#UFC238",
#     "url": "http://twitter.com/search?q=%23UFC238",
#     "promoted_content": null,
#     "query": "%23UFC238",
#     "tweet_volume": 131921
#    },
#    {
#     "name": "KENTA",
#     "url": "http://twitter.com/search?q=KENTA",
#     "promoted_content": null,
#     "query": "KENTA",
#     "tweet_volume": 25880
#    },
#    {
#     "name": "Dragon Lee",
#     "url": "http://twitter.com/search?q=%22Dragon+Lee%22",
#     "promoted_content": null,
#     "query": "%22Dragon+Lee%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ThingsSatanWouldSay",
#     "url": "http://twitter.com/search?q=%23ThingsSatanWouldSay",
#     "promoted_content": null,
#     "query": "%23ThingsSatanWouldSay",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MySaturdayNightIn3Words",
#     "url": "http://twitter.com/search?q=%23MySaturdayNightIn3Words",
#     "promoted_content": null,
#     "query": "%23MySaturdayNightIn3Words",
#     "tweet_volume": null
#    },
#    {
#     "name": "#RespectOurEuphoria",
#     "url": "http://twitter.com/search?q=%23RespectOurEuphoria",
#     "promoted_content": null,
#     "query": "%23RespectOurEuphoria",
#     "tweet_volume": 261234
#    },
#    {
#     "name": "Taichi",
#     "url": "http://twitter.com/search?q=Taichi",
#     "promoted_content": null,
#     "query": "Taichi",
#     "tweet_volume": null
#    },
#    {
#     "name": "henry cejudo",
#     "url": "http://twitter.com/search?q=%22henry+cejudo%22",
#     "promoted_content": null,
#     "query": "%22henry+cejudo%22",
#     "tweet_volume": 14991
#    },
#    {
#     "name": "Kumar Rocker",
#     "url": "http://twitter.com/search?q=%22Kumar+Rocker%22",
#     "promoted_content": null,
#     "query": "%22Kumar+Rocker%22",
#     "tweet_volume": 13802
#    },
#    {
#     "name": "Ishii",
#     "url": "http://twitter.com/search?q=Ishii",
#     "promoted_content": null,
#     "query": "Ishii",
#     "tweet_volume": null
#    },
#    {
#     "name": "Luxord",
#     "url": "http://twitter.com/search?q=Luxord",
#     "promoted_content": null,
#     "query": "Luxord",
#     "tweet_volume": null
#    },
#    {
#     "name": "G1 Climax",
#     "url": "http://twitter.com/search?q=%22G1+Climax%22",
#     "promoted_content": null,
#     "query": "%22G1+Climax%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Nomura",
#     "url": "http://twitter.com/search?q=Nomura",
#     "promoted_content": null,
#     "query": "Nomura",
#     "tweet_volume": null
#    },
#    {
#     "name": "Canelo",
#     "url": "http://twitter.com/search?q=Canelo",
#     "promoted_content": null,
#     "query": "Canelo",
#     "tweet_volume": null
#    },
#    {
#     "name": "Tony Ferguson",
#     "url": "http://twitter.com/search?q=%22Tony+Ferguson%22",
#     "promoted_content": null,
#     "query": "%22Tony+Ferguson%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Sanada",
#     "url": "http://twitter.com/search?q=Sanada",
#     "promoted_content": null,
#     "query": "Sanada",
#     "tweet_volume": null
#    },
#    {
#     "name": "Jessica Eye",
#     "url": "http://twitter.com/search?q=%22Jessica+Eye%22",
#     "promoted_content": null,
#     "query": "%22Jessica+Eye%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Roxas",
#     "url": "http://twitter.com/search?q=Roxas",
#     "promoted_content": null,
#     "query": "Roxas",
#     "tweet_volume": null
#    },
#    {
#     "name": "Moraes",
#     "url": "http://twitter.com/search?q=Moraes",
#     "promoted_content": null,
#     "query": "Moraes",
#     "tweet_volume": 22751
#    },
#    {
#     "name": "KH3 DLC",
#     "url": "http://twitter.com/search?q=%22KH3+DLC%22",
#     "promoted_content": null,
#     "query": "%22KH3+DLC%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Verb",
#     "url": "http://twitter.com/search?q=Verb",
#     "promoted_content": null,
#     "query": "Verb",
#     "tweet_volume": 13080
#    },
#    {
#     "name": "Yoshi Hashi",
#     "url": "http://twitter.com/search?q=%22Yoshi+Hashi%22",
#     "promoted_content": null,
#     "query": "%22Yoshi+Hashi%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Chase Owens",
#     "url": "http://twitter.com/search?q=%22Chase+Owens%22",
#     "promoted_content": null,
#     "query": "%22Chase+Owens%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "valentina",
#     "url": "http://twitter.com/search?q=valentina",
#     "promoted_content": null,
#     "query": "valentina",
#     "tweet_volume": 25347
#    },
#    {
#     "name": "moxley in the g1",
#     "url": "http://twitter.com/search?q=%22moxley+in+the+g1%22",
#     "promoted_content": null,
#     "query": "%22moxley+in+the+g1%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Khabib",
#     "url": "http://twitter.com/search?q=Khabib",
#     "promoted_content": null,
#     "query": "Khabib",
#     "tweet_volume": null
#    },
#    {
#     "name": "Shibata",
#     "url": "http://twitter.com/search?q=Shibata",
#     "promoted_content": null,
#     "query": "Shibata",
#     "tweet_volume": null
#    },
#    {
#     "name": "Liger",
#     "url": "http://twitter.com/search?q=Liger",
#     "promoted_content": null,
#     "query": "Liger",
#     "tweet_volume": null
#    },
#    {
#     "name": "Tama Tonga",
#     "url": "http://twitter.com/search?q=%22Tama+Tonga%22",
#     "promoted_content": null,
#     "query": "%22Tama+Tonga%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Broken Clocks",
#     "url": "http://twitter.com/search?q=%22Broken+Clocks%22",
#     "promoted_content": null,
#     "query": "%22Broken+Clocks%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "shevchenko",
#     "url": "http://twitter.com/search?q=shevchenko",
#     "promoted_content": null,
#     "query": "shevchenko",
#     "tweet_volume": 21043
#    },
#    {
#     "name": "#INDvAUS",
#     "url": "http://twitter.com/search?q=%23INDvAUS",
#     "promoted_content": null,
#     "query": "%23INDvAUS",
#     "tweet_volume": 30231
#    },
#    {
#     "name": "#protectmamamoo",
#     "url": "http://twitter.com/search?q=%23protectmamamoo",
#     "promoted_content": null,
#     "query": "%23protectmamamoo",
#     "tweet_volume": 30107
#    },
#    {
#     "name": "#SundayMorning",
#     "url": "http://twitter.com/search?q=%23SundayMorning",
#     "promoted_content": null,
#     "query": "%23SundayMorning",
#     "tweet_volume": 10381
#    },
#    {
#     "name": "#SundayThoughts",
#     "url": "http://twitter.com/search?q=%23SundayThoughts",
#     "promoted_content": null,
#     "query": "%23SundayThoughts",
#     "tweet_volume": 19323
#    },
#    {
#     "name": "#hunterxhunter",
#     "url": "http://twitter.com/search?q=%23hunterxhunter",
#     "promoted_content": null,
#     "query": "%23hunterxhunter",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TheBreastSongsEver",
#     "url": "http://twitter.com/search?q=%23TheBreastSongsEver",
#     "promoted_content": null,
#     "query": "%23TheBreastSongsEver",
#     "tweet_volume": null
#    },
#    {
#     "name": "#NCTzenSelcaDay",
#     "url": "http://twitter.com/search?q=%23NCTzenSelcaDay",
#     "promoted_content": null,
#     "query": "%23NCTzenSelcaDay",
#     "tweet_volume": 10519
#    },
#    {
#     "name": "#G129",
#     "url": "http://twitter.com/search?q=%23G129",
#     "promoted_content": null,
#     "query": "%23G129",
#     "tweet_volume": null
#    },
#    {
#     "name": "#JoJosBizarreAdventure",
#     "url": "http://twitter.com/search?q=%23JoJosBizarreAdventure",
#     "promoted_content": null,
#     "query": "%23JoJosBizarreAdventure",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Toonami",
#     "url": "http://twitter.com/search?q=%23Toonami",
#     "promoted_content": null,
#     "query": "%23Toonami",
#     "tweet_volume": null
#    },
#    {
#     "name": "#SundayMotivation",
#     "url": "http://twitter.com/search?q=%23SundayMotivation",
#     "promoted_content": null,
#     "query": "%23SundayMotivation",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MyUndesirableSkill",
#     "url": "http://twitter.com/search?q=%23MyUndesirableSkill",
#     "promoted_content": null,
#     "query": "%23MyUndesirableSkill",
#     "tweet_volume": null
#    },
#    {
#     "name": "#RandomThoughtsInAnElevator",
#     "url": "http://twitter.com/search?q=%23RandomThoughtsInAnElevator",
#     "promoted_content": null,
#     "query": "%23RandomThoughtsInAnElevator",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Shippuden",
#     "url": "http://twitter.com/search?q=%23Shippuden",
#     "promoted_content": null,
#     "query": "%23Shippuden",
#     "tweet_volume": null
#    },
#    {
#     "name": "#SeductiveSunday",
#     "url": "http://twitter.com/search?q=%23SeductiveSunday",
#     "promoted_content": null,
#     "query": "%23SeductiveSunday",
#     "tweet_volume": null
#    },
#    {
#     "name": "#SwordArtOnline",
#     "url": "http://twitter.com/search?q=%23SwordArtOnline",
#     "promoted_content": null,
#     "query": "%23SwordArtOnline",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ShakespeareSunday",
#     "url": "http://twitter.com/search?q=%23ShakespeareSunday",
#     "promoted_content": null,
#     "query": "%23ShakespeareSunday",
#     "tweet_volume": null
#    },
#    {
#     "name": "#G1Climax",
#     "url": "http://twitter.com/search?q=%23G1Climax",
#     "promoted_content": null,
#     "query": "%23G1Climax",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2019-06-09T10:00:06Z",
#   "created_at": "2019-06-09T09:51:39Z",
#   "locations": [
#    {
#     "name": "United States",
#     "woeid": 23424977
#    }
#   ]
#  }
# ]

# %% [markdown]
# ## Example 4. Computing the intersection of two sets of trends

# %%
trends_set = {}
trends_set['world'] = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

trends_set['us'] = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

trends_set['san diego'] = set([trend['name'] 
                     for trend in local_trends[0]['trends']])

# %%
for loc in ['world','us','san diego']:
    print(('-'*10,loc))
    print((','.join(trends_set[loc])))

# %%
print(( '='*10,'intersection of world and us'))
print((trends_set['world'].intersection(trends_set['us'])))

print(('='*10,'intersection of us and san-diego'))
print((trends_set['san diego'].intersection(trends_set['us'])))

# %% [markdown]
# ## Example 5. Collecting search results

# %% [markdown]
# Set the variable `q` to a trending topic,
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter

# %%
q = '#MTVAwards' 

number = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=number)

statuses = search_results['statuses']

# %%
len(statuses)
print(statuses)

# %% [markdown]
# Twitter often returns duplicate results, we can filter them out checking for duplicate texts:

# %%
all_text = []
filtered_statuses = []
for s in statuses:
    if not s["text"] in all_text:
        filtered_statuses.append(s)
        all_text.append(s["text"])
statuses = filtered_statuses

# %%
len(statuses)

# %%
[s['text'] for s in search_results['statuses']]

# %%
# Show one sample search result by slicing the list...
print(json.dumps(statuses[0], indent=1))

# %%
# The result of the list comprehension is a list with only one element that
# can be accessed by its index and set to the variable t
t = statuses[0]
#[ status for status in statuses 
#          if status['id'] == 316948241264549888 ][0]

# Explore the variable t to get familiarized with the data structure...

print(t['retweet_count'])
print(t['retweeted'])

# %% [markdown]
# ## Example 6. Extracting text, screen names, and hashtags from tweets

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# %%
# Explore the first 5 items for each...

print(json.dumps(status_texts[0:5], indent=1))
print(json.dumps(screen_names[0:5], indent=1)) 
print(json.dumps(hashtags[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))

# %% [markdown]
# ## Example 7. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print(c.most_common()[:10]) # top 10
    print()

# %% [markdown]
# ## Example 8. Create a prettyprint function to display tuples in a nice tabular format

# %%
def prettyprint_counts(label, list_of_tuples):
    print("\n{:^20} | {:^6}".format(label, "Count"))
    print("*"*40)
    for k,v in list_of_tuples:
        print("{:20} | {:>6}".format(k,v))

# %%
for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    
    c = Counter(data)
    prettyprint_counts(label, c.most_common()[:10])

# %% [markdown]
# ## Example 9. Finding the most popular retweets

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text'].replace("\n","\\")) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if 'retweeted_status' in status
           ]

# %% [markdown]
# We can build another `prettyprint` function to print entire tweets with their retweet count.
#
# We also want to split the text of the tweet in up to 3 lines, if needed.

# %%
row_template = "{:^7} | {:^15} | {:50}"
def prettyprint_tweets(list_of_tuples):
    print()
    print(row_template.format("Count", "Screen Name", "Text"))
    print("*"*60)
    for count, screen_name, text in list_of_tuples:
        print(row_template.format(count, screen_name, text[:50]))
        if len(text) > 50:
            print(row_template.format("", "", text[50:100]))
            if len(text) > 100:
                print(row_template.format("", "", text[100:]))

# %%
# Slice off the first 5 from the sorted results and display each item in the tuple

prettyprint_tweets(sorted(retweets, reverse=True)[:10])
